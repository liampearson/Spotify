# %% [markdown]
# # Spotify Streaming Data Analysis
#
# ### Checkout my youtube tutorial which explains the code 👉 [Video HERE](https://youtu.be/OLxqUuiwO_g?si=iPFvwvNzFHykxzhq)

# %% [markdown]
# ## 1️⃣ Import Data
#
# Your Spotify data will come to you as many .json files

# %%
#Change this to where your data is
parent_folder = "/Users/name/Downloads/Spotify Extended Streaming History/"

file_name = "Streaming_History_Audio_*.json"

# %%
import pandas as pd
import glob

df = pd.DataFrame()

for file in glob.glob(parent_folder+file_name):
    temp = pd.read_json(file)
    df = pd.concat([df, temp])
# Out:
# /var/folders/kk/cpbqcncj10l04nn3d5y056yc0000gn/T/ipykernel_83741/1631207755.py:8: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   df = pd.concat([df, temp])

# %%
print(df.shape)
df
# Out:
# (248041, 19)
#                          ts               platform  ms_played conn_country  \
# 0      2013-11-24T03:10:53Z    OS X 10.9.0 [x86 4]     163319           AU
# 1      2013-11-24T03:11:07Z    OS X 10.9.0 [x86 4]      14584           AU
# 2      2013-11-24T03:14:14Z    OS X 10.9.0 [x86 4]     187026           AU
# 3      2013-11-24T03:17:31Z    OS X 10.9.0 [x86 4]     204053           AU
# 4      2013-11-24T03:57:10Z  iOS 7.0.4 (iPhone4,1)     224295           AU
# ...                     ...                    ...        ...          ...
# 16965  2016-07-18T21:25:42Z  iOS 9.3.2 (iPhone8,1)     203196           AU
# 16966  2016-07-18T21:25:46Z  iOS 9.3.2 (iPhone8,1)          0           AU
# 16967  2016-07-18T21:25:51Z  iOS 9.3.2 (iPhone8,1)       4667           AU
# 16968  2016-07-18T21:25:56Z  iOS 9.3.2 (iPhone8,1)       4760           AU
# 16969  2016-07-18T21:29:12Z  iOS 9.3.2 (iPhone8,1)     196826           AU
#
#       user_agent_decrypted master_metadata_track_name  \
# 0                  unknown                     Timber
# 1                  unknown                       Bros
# 2                  unknown                  All Night
# 3                  unknown                     Timber
# 4                  unknown                       Roar
# ...                    ...                        ...
# 16965              unknown             So Sentimental
# 16966              unknown              Pokemon Theme
# 16967              unknown              Pokemon Theme
# 16968              unknown              Pokemon Theme
# 16969              unknown              Pokemon Theme
#
#       master_metadata_album_artist_name  master_metadata_album_album_name  \
# 0                               Pitbull                            Timber
# 1                            Wolf Alice                              Bros
# 2                             Icona Pop              THIS IS... ICONA POP
# 3                               Pitbull                            Timber
# 4                            Katy Perry                             PRISM
# ...                                 ...                               ...
# 16965                      Violent Soho                              WACO
# 16966                           Pokémon  Pokemon X - Ten Years Of Pokemon
# 16967                           Pokémon  Pokemon X - Ten Years Of Pokemon
# 16968                           Pokémon  Pokemon X - Ten Years Of Pokemon
# 16969                           Pokémon  Pokemon X - Ten Years Of Pokemon
#
#                           spotify_track_uri episode_name episode_show_name  \
# 0      spotify:track:1zHlj4dQ8ZAtrayhuDDmkY          NaN               NaN
# 1      spotify:track:57thHrPMP26JFKVM5M2znL          NaN               NaN
# 2      spotify:track:1ADGydOgtuzBNmdFpcQGLB          NaN               NaN
# 3      spotify:track:1zHlj4dQ8ZAtrayhuDDmkY          NaN               NaN
# 4      spotify:track:3bDGwl0X3EjQmIyFD1uif5          NaN               NaN
# ...                                     ...          ...               ...
# 16965  spotify:track:2gPASVJHzAHYeGHeus8IBr         None              None
# 16966  spotify:track:6xG2ZGudUgtV235xvDlSEt         None              None
# 16967  spotify:track:6xG2ZGudUgtV235xvDlSEt         None              None
# 16968  spotify:track:6xG2ZGudUgtV235xvDlSEt         None              None
# 16969  spotify:track:6xG2ZGudUgtV235xvDlSEt         None              None
#
#       spotify_episode_uri reason_start reason_end  shuffle skipped  offline  \
# 0                     NaN      unknown      popup    False     1.0    False
# 1                     NaN        popup      popup    False     1.0    False
# 2                     NaN        popup  trackdone    False     0.0    False
# 3                     NaN    trackdone  trackdone    False     0.0    False
# 4                     NaN               trackdone    False     0.0    False
# ...                   ...          ...        ...      ...     ...      ...
# 16965                None    trackdone    endplay    False     NaN    False
# 16966                None     clickrow    endplay    False     NaN    False
# 16967                None     clickrow    endplay    False     NaN    False
# 16968                None     clickrow    endplay    False     NaN    False
# 16969                None     clickrow  trackdone    False     NaN    False
#
#        offline_timestamp  incognito_mode
# 0                      0           False
# 1                      0           False
# 2                      0           False
# 3                      0           False
# 4                      0           False
# ...                  ...             ...
# 16965                  0           False
# 16966                  0           False
# 16967                  0           False
# 16968                  0           False
# 16969                  0           False
#
# [248041 rows x 19 columns]

# %% [markdown]
# ## 2️⃣ Preprocessing
# ### 🕰️ Convert to Timestamp & Localize

# %%
#convert to datetime
df['ts'] = pd.to_datetime(df['ts'], format="%Y-%m-%dT%H:%M:%SZ", utc=True)

#localise
import pytz
my_tz = pytz.timezone("Australia/Sydney")

#convert timezone
df['ts'] = df['ts'].dt.tz_convert(my_tz)

# %%
#sort data in chronological order
df.sort_values(by='ts', inplace=True)

# %% [markdown]
# ### 🗓️ Extract the `year`

# %%
df['year'] = df['ts'].dt.year
df[['ts', 'year']]
# Out:
#                            ts  year
# 0   2013-11-24 14:10:53+11:00  2013
# 1   2013-11-24 14:11:07+11:00  2013
# 2   2013-11-24 14:14:14+11:00  2013
# 3   2013-11-24 14:17:31+11:00  2013
# 4   2013-11-24 14:57:10+11:00  2013
# ..                        ...   ...
# 243 2024-09-27 07:43:03+10:00  2024
# 244 2024-09-27 07:48:11+10:00  2024
# 245 2024-09-27 07:51:19+10:00  2024
# 246 2024-09-27 07:55:15+10:00  2024
# 247 2024-09-27 09:00:47+10:00  2024
#
# [248041 rows x 2 columns]

# %% [markdown]
# ## 4️⃣ Who Was the Most Played Artist in 2024

# %%
df[df['year']==2024].groupby('master_metadata_album_artist_name')['master_metadata_album_artist_name'].count().sort_values(ascending=False)
# Out:
# master_metadata_album_artist_name
# Taylor Swift         3155
# Charli xcx            975
# Romy                  504
# Chappell Roan         474
# Sabrina Carpenter     330
#                      ...
# Odie Leigh              1
# F.HERO                  1
# Okami Sky               1
# Old Mervs               1
# Laura Dreyfuss          1
# Name: master_metadata_album_artist_name, Length: 1105, dtype: int64
